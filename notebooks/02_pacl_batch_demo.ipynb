# %% [markdown]
# # PACL Batch Demo
#
# This notebook demonstrates the multi-profile PACL Layer 1 workflow.
#
# It loads the generated batch summary, displays the current profile set,
# and shows the comparison figures.

# %%
from pathlib import Path

import pandas as pd
from IPython.display import Image, display

repo_root = Path.cwd().resolve().parent
summary_path = repo_root / 'docs' / 'batch_outputs' / 'batch_summary.csv'
comparison_path = repo_root / 'docs' / 'batch_outputs' / 'batch_comparison.png'
site_comparison_path = repo_root / 'docs' / 'batch_outputs' / 'site_case_comparison.png'

summary_path, comparison_path, site_comparison_path
# Out:
# (PosixPath('/home/nabiel/projects/pacl-gulf-atmosphere/docs/batch_outputs/batch_summary.csv'),
#  PosixPath('/home/nabiel/projects/pacl-gulf-atmosphere/docs/batch_outputs/batch_comparison.png'),
#  PosixPath('/home/nabiel/projects/pacl-gulf-atmosphere/docs/batch_outputs/site_case_comparison.png'))

# %%
df = pd.read_csv(summary_path)
df
# Out:
#                             file      site        date   case classification  \
# 0      doha_2026-03-12_clear.csv      doha  2026-03-12  clear          CLEAR
# 1       doha_2026-03-12_duct.csv      doha  2026-03-12   duct      DUCT_RISK
# 2       doha_2026-03-12_hazy.csv      doha  2026-03-12   hazy   TRANSITIONAL
# 3    dukhan_2026-03-12_clear.csv    dukhan  2026-03-12  clear          CLEAR
# 4     dukhan_2026-03-12_duct.csv    dukhan  2026-03-12   duct      DUCT_RISK
# 5     dukhan_2026-03-12_hazy.csv    dukhan  2026-03-12   hazy   TRANSITIONAL
# 6  mesaieed_2026-03-12_clear.csv  mesaieed  2026-03-12  clear          CLEAR
# 7   mesaieed_2026-03-12_duct.csv  mesaieed  2026-03-12   duct      DUCT_RISK
# 8   mesaieed_2026-03-12_hazy.csv  mesaieed  2026-03-12   hazy   TRANSITIONAL
#
#   duct_risk swir_quality radar_stability  min_gradient  mean_gradient  \
# 0       Low         High            High     -2.396209      -2.033515
# 1      High       Medium             Low    -22.318541     -16.017992
# 2  Moderate       Medium          Medium    -10.640368      -8.639711
# 3       Low         High            High     -1.664643      -1.355473
# 4      High       Medium             Low    -19.149671     -13.309404
# 5  Moderate       Medium          Medium     -9.491052      -7.567409
# 6       Low         High            High     -2.245812      -1.893602
# 7      High       Medium             Low    -21.532641     -15.149266
# 8  Moderate       Medium          Medium    -11.284087      -9.129405
#
#                                  plot_file
# 0      doha_2026-03-12_clear_m_profile.png
# 1       doha_2026-03-12_duct_m_profile.png
# 2       doha_2026-03-12_hazy_m_profile.png
# 3    dukhan_2026-03-12_clear_m_profile.png
# 4     dukhan_2026-03-12_duct_m_profile.png
# 5     dukhan_2026-03-12_hazy_m_profile.png
# 6  mesaieed_2026-03-12_clear_m_profile.png
# 7   mesaieed_2026-03-12_duct_m_profile.png
# 8   mesaieed_2026-03-12_hazy_m_profile.png

# %% [markdown]
# ## Batch Comparison Figure

# %%
display(Image(filename=str(comparison_path)))

# %% [markdown]
# ## Site / Case Comparison Figure

# %%
display(Image(filename=str(site_comparison_path)))

# %% [markdown]
# ## Interpretation
#
# This notebook shows that the PACL Layer 1 prototype now supports multiple
# profile files with no code edits required.
#
# New files can be added to `data/raw/profiles/` using the convention:
#
# `<site>_<date>_<case>.csv`
#
# and will automatically be included in the batch run.
